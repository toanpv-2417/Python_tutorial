# %%
import pandas as pd

# %%
# df = pd.DataFrame([[1, 2], [4, None],[7, None]],
#      index=['cobra', 'viper', 'sidewinder'],
#      columns=['max_speed', 'shield'])

# %%
# df['max_speed']

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df = df.dropna(subset=['country'])

# %%
df = df.head(75)

# %%
df
# Out:
#     show_id     type                          title         director  \
# 0        s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 1        s2  TV Show                  Blood & Water              NaN
# 4        s5  TV Show                   Kota Factory              NaN
# 7        s8    Movie                        Sankofa     Haile Gerima
# 8        s9  TV Show  The Great British Baking Show  Andy Devonshire
# ..      ...      ...                            ...              ...
# 116    s117    Movie                         Dhanak  Nagesh Kukunoor
# 117    s118    Movie                  Final Account     Luke Holland
# 118    s119    Movie                        Gurgaon    Shanker Raman
# 120    s121  TV Show           Heroes of Goo Jit Zu              NaN
# 122    s123    Movie                     In the Cut     Jane Campion
#
#                                                   cast  \
# 0                                                  NaN
# ...

# %%
df['country'].str.split(',')
# Out:
# 0                                        [United States]
# 1                                         [South Africa]
# 4                                                [India]
# 7      [United States,  Ghana,  Burkina Faso,  United...
# 8                                       [United Kingdom]
#                              ...
# 116                                              [India]
# 117                     [United Kingdom,  United States]
# 118                                              [India]
# 120                                          [Australia]
# 122    [United Kingdom,  Australia,  France,  United ...
# Name: country, Length: 75, dtype: object

# %%
df['country'] = [countries[0] for countries in df['country'].str.split(',')]

# %%
df['country']
# Out:
# 0       United States
# 1        South Africa
# 4               India
# 7       United States
# 8      United Kingdom
#             ...
# 116             India
# 117    United Kingdom
# 118             India
# 120         Australia
# 122    United Kingdom
# Name: country, Length: 75, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
country_counts = pd.DataFrame(
  df['country'].value_counts().rename_axis(
    'countries').reset_index(name='counts')
  ).sort_values(by=['counts'])

# %%
pd.DataFrame(df['country'].value_counts())
# Out:
#                 country
# United States        24
# Japan                13
# India                10
# United Kingdom        9
# Australia             3
# Nigeria               3
# South Africa          2
# Spain                 2
# France                2
# Germany               1
# Mexico                1
# Turkey                1
# Finland               1
# China                 1
# Belgium               1
# South Korea           1

# %%
country_counts
# Out:
#          countries  counts
# 9          Germany       1
# 10          Mexico       1
# 11          Turkey       1
# 12         Finland       1
# 13           China       1
# 14         Belgium       1
# 15     South Korea       1
# 6     South Africa       2
# 7            Spain       2
# 8           France       2
# 4        Australia       3
# 5          Nigeria       3
# 3   United Kingdom       9
# 2            India      10
# 1            Japan      13
# 0    United States      24
