# %% [markdown]
# # Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
plt.style.use('seaborn-whitegrid')

# %%
plt.plot()
# Out:
# []

# %%
x = [1,2,3,4]
y= [10,8,6,9]
plt.plot(x,y,color="red")

# %% [markdown]
# # Pylot API vs Object oriented API
# * Pylot API -> quickly
# * OO API -> advance

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), color="blue", linestyle="dashed", label="sin(x)");
plt.plot(x, np.cos(x), color="red", label="cos(x)")

plt.title("Toan graph")
plt.xlabel("X");
plt.ylabel("F(x)");

#plt.xlim([0,4])
#plt.ylim([-0.7, 0.6])
#plt.axis([0, 4, -0.7, 0.6])
# plt.axis("tight")
plt.axis("equal")
plt.legend();

# %% [markdown]
# # Object Orientd API

# %%
#1 prepare data
x = [1,2,3,4]
y = [11,22,33,44]

#2. setup plot
fig,ax = plt.subplots(figsize=(5,5)) #Figure size = width va height of plot

#3. Plot data

ax.plot(x,y)
ax.set(title="Toan grap con ",
        xlabel = "x-axis",
        ylabel = "y-axis"
      )
# Out:
# [Text(0.5, 1.0, 'Toan grap con '),
#  Text(0.5, 0, 'x-axis'),
#  Text(0, 0.5, 'y-axis')]

# %% [markdown]
# # 2. Most common type of Matplotlib plots

# %% [markdown]
# * line
# * scatter
# * bar
# * hist
# * subplots

# %% [markdown]
# # Line

# %%
x = np.linspace(0,10,100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
#OO API plot a line chart

fig,ax = plt.subplots()
ax.plot(x,x**3)

# %% [markdown]
# # Scatter : Đồ thị phân tán

# %%
plt.scatter(x,np.exp(x))

# %%
#OO API

#Prepara data
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)
sizes = 1000*rng.rand(100)
colors = rng.rand(100)

fig,ax = plt.subplots()

img1 = ax.scatter(x,y,c=colors,s = sizes,cmap='viridis',alpha= 0.8)

fig.colorbar(img1)
# Out:
# /var/folders/9h/kgy3h10n3yj_fmssgsctv081629zrf/T/ipykernel_2340/2196534019.py:15: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(img1)

# %% [markdown]
# # Bar : Biêủ đồ cột
# * Vertical
# * Horizontal

# %%
#Prepare Data from a python dictionary

# %%
soft_drink_prices = {"coke":10,
                     "Pessi":12,
                     "Spire":4}
fig , ax = plt.subplots()
ax.bar(soft_drink_prices.keys(),soft_drink_prices.values())
ax.set(title="Tỉ lệ người nghiện ", ylabel="Price ($)" ,xlabel= "matuy")
# Out:
# [Text(0.5, 1.0, 'Tỉ lệ người nghiện '),
#  Text(0, 0.5, 'Price ($)'),
#  Text(0.5, 0, 'matuy')]

# %%
fig , ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()),list(soft_drink_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # 4.Histogram: Thể hiện tần suất dạng cột

# %%
#Prepare data

# %%
student_height = np.random.normal(170,10,250)

# %%
student_height[:5]
# Out:
# array([177.43063687, 170.21610611, 188.2132095 , 153.62057267,
#        170.94894294])

# %%
#pylot API
plt.hist(student_height,bins=20);

# %% [markdown]
# # Subplots

# %%
#Option1:
fig,((ax1,ax2),(ax3,ax4))= plt.subplots(nrows=2,
                                         ncols=2,
                                        figsize=(10,5)
                     )
#Plot data to each axis
ax1.plot(x,x/2)
ax1.plot(x,x*2)

ax2.scatter(np.random.random(10),np.random.random(10))

ax3.bar(soft_drink_prices.keys(),soft_drink_prices.values())

ax4.hist(student_height,bins=20);

# %%
#Option2:
fig, ax = plt.subplots(
    nrows = 2,
    ncols= 2,
    figsize=(10,5)
)

#Plot data to each axis
ax[0,0].plot(x,x/2)
ax[0,0].plot(x,x*2)

ax[0,1].scatter(np.random.random(10),np.random.random(10))

ax[1,0].bar(soft_drink_prices.keys(),soft_drink_prices.values())

ax[1,1].hist(student_height,bins=20);
